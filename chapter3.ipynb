# %% [markdown]
# ## Exercise 1.
# What is the absolute value of the integers −123, 27 and 0?
#
# **solution:**
# - |-123| = 123
# - |27| = 27
# - |0| = 0
# ## Exercise 2.
# Compute the factorization of 30030 and double-check your results using Sage.
#
# **solution:**

# %%
factor(30030)
# Out:
# 2 * 3 * 5 * 7 * 11 * 13

# %% [markdown]
# ## Exercise 3.
# Consider the following equation:
#
# $4x + 21 = 5$
#
# Compute the set of all solutions for x under the following alternative assumptions:
# 1. The equation is defined over the set of natural numbers.
# 2. The equation is defined over the set of integers.
#
# **solution:**
# 1. $\{ \emptyset \}$.
# 2. x = -4

# %% [markdown]
# ## Exercise 4.
# Consider the following equation:
#
# $2x^3 − x^2 − 2x = −1$
#
# Compute the set of all solutions x under the following assumptions:
# 1. The equation is defined over the set of natural numbers.
# 2. The equation is defined over the set of integers.
# 3. The equation is defined over the set of rational numbers.
#
# **solution:**

# %%
# The natural numbers does not form a ring
intpoly.<y> = PolynomialRing(ZZ)
ratpoly.<z> = PolynomialRing(QQ)

var('x')
eq1 = 2*x^3 - x^2 - 2*x + 1 == 0
eq2 = 2*y^3 - y^2 - 2*y + 1
eq3 = 2*z^3 - z^2 - 2*z + 1

sol_1 = factor(eq1)
sol_2 = factor(eq2)
sol_3 = factor(eq3)

print(f"1. {sol_1}")
print(f"2. {sol_2}")
print(f"3. {sol_3}")
# Out:
# 1. (2*x - 1)*(x + 1)*(x - 1) == 0
# 2. (y - 1) * (y + 1) * (2*y - 1)
# 3. (2) * (z - 1) * (z - 1/2) * (z + 1)

# %% [markdown]
# ## Exercise 5 (Integer Long Division).
# Find an $m \in Z$ and an $r \in N$ with $0 <= r < |b|$ such that
# $a = mb + r$ holds for the following pairs:
# - (a, b) = (27, 5)
# - (a, b) = (27, −5)
# - (a, b) = (127, 0)
# - (a, b) = (−1687, 11)
# - (a, b) = (0, 7)

# %%
a_b_s = [(27, 5), (27, -5), (127, 0), (-1687, 11), (0, 7)]
for a, b in a_b_s:
    if b == 0:
        print(f"for a = {a} and b = {b}),no solution when b = 0")
        continue
    m, r = a // b, a % b
    print(f"for a = {a} and b = {b}), {a} = {m} * {b} + {r} ")
    assert(a == b * m + r)
# Out:
# for a = 27 and b = 5), 27 = 5 * 5 + 2
# for a = 27 and b = -5), 27 = -6 * -5 + -3
# for a = 127 and b = 0),no solution when b = 0
# for a = -1687 and b = 11), -1687 = -154 * 11 + 7
# for a = 0 and b = 7), 0 = 0 * 7 + 0

# %% [markdown]
# ## Exercise 6 (Long Division Algorithm).
# Using the programming language of your choice, write an algorithm that computes integer long division and handles all edge cases properly.

# %% [markdown]
# ## Excercise 7 (Binary Representation).
# Write an algorithm that computes the binary representation 3.13 of any non-negative integer.

# %%
def NN_to_bin(n: int, b: int = '', uneven: bool = False) -> int:
    if n == 0: return b[::-1]
    return NN_to_bin(n // 2 , b + str(n % 2), uneven)

for _ in range(1000):
    a = randint(1, 10**6)
    assert(NN_to_bin(a) == NN(a).str(2))

# %% [markdown]
# ## Exercise 8 (Extended Euclidean Algorithm).
# Find integers $s,t \in Z$ such that $gcd(a, b) = sa + tb$ holds for the following pairs:
# - (a, b) = (45, 10)
# - (a, b) = (13, 11)
# - (a, b) = (13, 12)

# %%
def EEA(a,b):
    if b == 0: return (a,1,0)
    d,s,t = EEA(b, a % b)
    return (d, t, s - (a//b) * t)

abs = [(45, 10), (13, 11), (13, 12)]
for a, b in abs:
    gcd, s, t = EEA(a, b)
    print(f"for a = {a} and b = {b}, {gcd} = {s} a + {t} b")
# Out:
# for a = 45 and b = 10, 5 = 1 a + -4 b
# for a = 13 and b = 11, 1 = -5 a + 6 b
# for a = 13 and b = 12, 1 = 1 a + -1 b

# %% [markdown]
# ## Exercise 9 (Towards Prime fields).
# Let $n \in N$ be a natural number and p a prime number, such that n < p. What is the greatest common divisor gcd(p, n)?
#
# **solution:** 1 else gcd(n, p) = a st a > 1, then a|p and thus p wouldn't be prime

# %% [markdown]
# ## Exercise 10.
# Find all numbers $k \in N$ with $0 <= k <= 100$ such that gcd(100, k) = 5.

# %%
numbers = []
for k in range(100):
    if k % 5 == 0 and not (k % 2 == 0 or k % 25 == 0):
        numbers.append(k)

numbers
# Out:
# [5, 15, 35, 45, 55, 65, 85, 95]

# %% [markdown]
# ## Exercise 11.
# Show that gcd(n, m) = gcd(n + m, m) for all $n, m \in N$.
#
# **solution:**
# let gcd(n, m) = d; d|n and d|m
#
# gcd(n + m, m) = s (n + m) + t (m); sincd d|n and d|m then d|n+m

# %% [markdown]
# ## Exercise 12.
# Consider exercise 8 again. Which pairs (a, b) from that exercise are coprime?
#
# **solution:** 2 & 3 because gcd(a,b) = 1

# %% [markdown]
# ## Exercise 13.
# Consider the octal positional system, which represents integers with 8 digits, usu-
# ally written as {0, 1, 2, 3, 4, 5, 6, 7}. Numbers in this system are characterized by the prefix 0o.
# Write the numbers 0o1354 and 0o777 into their decimal representation.

# %%
def octal_to_dec(n:str) -> int:
    assert(n[:2] == '0o')
    return sum(int(x) * 8 ** i for i, x in enumerate([*n[2:][::-1]]))

assert(NN(octal_to_dec('0o1354')).str(8) == '1354')
assert(NN(octal_to_dec('0o777')).str(8) == '777')

# %%
NN(octal_to_dec('0o1354')).str(8) =
# Out:
# ['4', '5', '3', '1']
# '1354'

# %% [markdown]
# ## Exercise 14.
# Which of the following pairs of numbers are congruent with respect to the modulus 13:

# %%
points = [(5, 19), (13, 0), (-4, 9), (0, 0)]
R = GF(13)

[(a,b) for a, b in points if R(a) == R(b) ]
# Out:
# [(13, 0), (-4, 9), (0, 0)]

# %% [markdown]
# ## Exercise 15.
# Find all integers x, such that the congruence $x \equiv 4\ (\textrm{mod}\ 6 )$ is satisfied.

# %%
R = Integers(6)

print([x for x in range(1000) if R(x) == 4])
# Out:
# [4, 10, 16, 22, 28, 34, 40, 46, 52, 58, 64, 70, 76, 82, 88, 94, 100, 106, 112, 118, 124, 130, 136, 142, 148, 154, 160, 166, 172, 178, 184, 190, 196, 202, 208, 214, 220, 226, 232, 238, 244, 250, 256, 262, 268, 274, 280, 286, 292, 298, 304, 310, 316, 322, 328, 334, 340, 346, 352, 358, 364, 370, 376, 382, 388, 394, 400, 406, 412, 418, 424, 430, 436, 442, 448, 454, 460, 466, 472, 478, 484, 490, 496, 502, 508, 514, 520, 526, 532, 538, 544, 550, 556, 562, 568, 574, 580, 586, 592, 598, 604, 610, 616, 622, 628, 634, 640, 646, 652, 658, 664, 670, 676, 682, 688, 694, 700, 706, 712, 718, 724, 730, 736, 742, 748, 754, 760, 766, 772, 778, 784, 790, 796, 802, 808, 814, 820, 826, 832, 838, 844, 850, 856, 862, 868, 874, 880, 886, 892, 898, 904, 910, 916, 922, 928, 934, 940, 946, 952, 958, 964, 970, 976, 982, 988, 994]

# %% [markdown]
# ## Exercise 16.
# Consider the modulus 13 and find all solutions x ∈ Z to the following congruence:
# $5x + 4 \equiv 28 + 2x\ (\textrm{mod}\ 13 )$
#
# **solution:**
#
# $ 3x \equiv 24\ (\textrm{mod}\ 13) \rightarrow 3x \equiv 11\ (\textrm{mod}\ 13 ) \rightarrow x \equiv 11 \cdot 3^{-1}\ (\textrm{mod}\ 13 )\rightarrow x \equiv 11 \cdot 9\ (\textrm{mod}\ 13 ) \rightarrow x \equiv 8\ (\textrm{mod}\ 13 )$
#
# $x \in \{ .., -5, 8, 21, 34, .. \}$
# ## Exercise 17.
# Consider the modulus 23 and find all solutions x ∈ Z to the following congruence:
# $69x \equiv 5\ (\textrm{mod}\ 23 )$
#
# **solution:**
#
# $69x \equiv 5\ (\textrm{mod}\ 23 ) \rightarrow 0 \cdot x \equiv 5\ (\textrm{mod}\ 23 )$
#
# $\forall x \in Z$
#
# ## Exercise 18.
# Consider the modulus 23 and find all solutions x ∈ Z to the following congruence:
# $69x \equiv 46\ (\textrm{mod}\ 23 )$
#
# **solution:**
#
# $69x \equiv 46\ (\textrm{mod}\ 23 ) \rightarrow 0 \cdot x \equiv 0 (\textrm{mod}\ 23 ) \rightarrow x \equiv 0 (\textrm{mod}\ 23 )$
#
# $\forall x \in Z$
#
# ## Exercise 19.
# Let a, b, k be integers, such that $a \equiv b\ (\textrm{mod}\ n )$ holds. Show $ak \equiv bk\ (\textrm{mod}\ n )$.
#
# **solution:**
#
# $a \equiv b\ (\textrm{mod}\ n ) \rightarrow a = c\cdot n + b \rightarrow k \cdot a = k \cdot (c\cdot n + b) \rightarrow   k \cdot a = k \cdot c\cdot n + k \cdot b \rightarrow  a \cdot k \equiv b \cdot k\ (\textrm{mod}\ n)$
#
# ## Exercise 20.
# Let a, n be integers, such that a and n are not coprime. For which b ∈ Z does the
# congruence $a \cdot x \equiv b\ (\textrm{mod}\ n )$ have a solution x and how does the solution set look in that case?
#
# **solution:**
#
# $gcd(a, n) = c,\ s.t.\ c > 1$
#
# $a \cdot x \equiv b\ (\textrm{mod}\ n ) \rightarrow a\cdot x = m\cdot n + b \rightarrow a \cdot x - m \cdot n = b \rightarrow c \cdot (a/c \cdot x - m \cdot n/c) = b \rightarrow a/c \cdot x - m \cdot n/c = b / c$
#
# x has only a solution if and only if c|b

# %% [markdown]
# ## Exercise 21.
# Define $Z_{13}$ as the the arithmetic modulo 13 analogously to example 11. Then
# consider the congruence from exercise 16 and rewrite it into an equation in $Z_{13}$.

# %%
Z13 = Integers(13)
Z13x = Z13['x']
Z13x([4, 5]) - Z13x([28, 2])
# Out:
# 3*x + 2

# %% [markdown]
# ## Exercise 22.
# Consider the modulus n = 24. Which of the integers 7, 1, 0, 805, −4255 have
# multiplicative inverses in modular 24 arithmetic? Compute the inverses, in case they exist.

# %%
Z24 = Integers(24)

for x in [7, 1, 0, 805, -4255]:
    gcd, s, _ = EEA(x, 24)
    if gcd == 1:
        assert(Z24(x) * Z24(s) == 1)
        print(f"integer {x} has a multiplicative inverse {s} in Z24")
# Out:
# integer 7 has a multiplicative inverse 7 in Z24
# integer 1 has a multiplicative inverse 1 in Z24
# integer 805 has a multiplicative inverse -11 in Z24
# integer -4255 has a multiplicative inverse -7 in Z24

# %% [markdown]
# ## Exercise 23.
# Find the set of all solutions to the congruence 17(2x + 5) − 4 ≡ 2x + 4 ( mod 5 ).
# Then project the congruence into $Z_5$ and solve the resulting equation in $Z_{5}$. Compare the results.

# %%
Z5 = Integers(5)
Z5x = Z5['x']
Z5x(17) * Z5x([5, 2]) - Z5x(4) - Z5x([4, 2])
# Out:
# 2*x + 2

# %% [markdown]
# **solution:**
#
# $ 2x \equiv -2\ (\textrm{mod}\ 5) \rightarrow 2x \equiv 3 \ (\textrm{mod}\ 5 ) \rightarrow x \equiv 3 \cdot 2^{-1} \ (\textrm{mod}\ 5 ) \rightarrow x \equiv 9 \ (\textrm{mod}\ 5 ) \rightarrow x \equiv 4 \ (\textrm{mod}\ 5 )$
#
# $x \in \{.., -1, 4, 9, ..\}$

# %% [markdown]
# ## Exercise 24.
# Find the set of all solutions to the congruence 17(2x + 5) − 4 ≡ 2x + 4 ( mod 6 ).
# Then project the congruence into $Z_6$ and try to solve the resulting equation in $Z_6$

# %%
Z6 = Integers(6)
Z6x = Z6['x']
Z6x(17) * Z6x([5, 2]) - Z6x(4) - Z6x([4, 2])
# Out:
# 2*x + 5

# %% [markdown]
# **solution:**
#
# $ 2x \equiv -5\ (\textrm{mod}\ 6) \rightarrow 2x \equiv 1 \ (\textrm{mod}\ 6 ) \rightarrow x \equiv 2^{-1} \ (\textrm{mod}\ 6 ) $
#
# $x \in \emptyset$

# %%
Z6(2)**-1
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[160], line 1
# ----> 1 Z6(Integer(2))**-Integer(1)
#
# File /private/var/tmp/sage-10.3-current/local/var/lib/sage/venv-python3.11.1/lib/python3.11/site-packages/sage/rings/finite_rings/integer_mod.pyx:2820, in sage.rings.finite_rings.integer_mod.IntegerMod_int.__pow__ (build/cythonized/sage/rings/finite_rings/integer_mod.c:40878)()
#    2818 res = mod_pow_int(self.ivalue, long_exp, self._modulus.int32)
#    2819 if invert:
# -> 2820     return ~self._new_c(res)
#    2821 else:
#    2822     return self._new_c(res)
#
# File /private/var/tmp/sage-10.3-current/local/var/lib/sage/venv-python3.11.1/lib/python3.11/site-packages/sage/rings/finite_rings/integer_mod.pyx:2838, in sage.rings.finite_rings.integer_mod.IntegerMod_int.__invert__ (build/cythonized/sage/rings/finite_rings/integer_mod.c:41055)()
#    2836 x = self._modulus.inverses[self.ivalue]
#    2837 if x is None:
# -> 2838     raise ZeroDivisionError(f"inverse of Mod({self}, {self._modulus.sageInteger}) does not exist")
#    2839 else:
#    2840     return x
#
# ZeroDivisionError: inverse of Mod(2, 6) does not exist
